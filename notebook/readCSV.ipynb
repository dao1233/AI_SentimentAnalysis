# %%
import pandas as pd
import numpy as np
import glob

# df = pd.read_csv('../data/raw/marvelRanarokExcel.csv')
# # df = pd.read_csv('marvelRanarok.csv', encoding="cp1252")

# # print(df.to_string())
# # print(df.loc[2, "review"])
# # print(df["review"].to_string())
# # print(df["review"].tolist())
# # print(pd.options.display.max_rows)
# print(df["sentiment"].value_counts())

# df = pd.read_csv('../data/raw/MarvelTrailerReview.csv')
# print(df["review"].tolist())


# Create empty list to store dataframes
dfs = []

# Read each CSV file and append to list
df = pd.read_csv('../data/raw/marvelRanarokExcel.csv')
dfs.append(df)
df = pd.read_csv('../data/raw/MarvelStudioAntManQuantumania.csv')
dfs.append(df)
df = pd.read_csv('../data/raw/MarvelTheFantasticFourFirstSteps.csv')
dfs.append(df)
df = pd.read_csv('../data/raw/MarvelTrailerReview.csv')
dfs.append(df)

# Concatenate all dataframes
combined_df = pd.concat(dfs, ignore_index=True)

# Save to new CSV file
combined_df.to_csv('../data/raw/dataTotal.csv', index=False)

df = pd.read_csv('../data/raw/dataTotal.csv')
print(df["sentiment"].value_counts())
# Out:
# sentiment
# negative    260
# positive    223
# neutral     133
# Name: count, dtype: int64
